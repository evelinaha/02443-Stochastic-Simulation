# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import geom
from scipy.stats.sampling import DiscreteAliasUrn
from scipy.stats import chisquare
import time
import random
import math
import simpy
import pandas as pd
from collections import Counter
from scipy.stats import ks_1samp
from scipy.linalg import expm
from lifelines.statistics import logrank_test
from scipy.linalg import norm

# %% [markdown]
# ### Part 1: Discrete-time model: Simulation / Estimation of Breast Cancer

# %% [markdown]
# Task 1

# %% [markdown]
# Task 2

# %% [markdown]
# Task 3

# %% [markdown]
# Task 4

# %% [markdown]
# Task 5

# %% [markdown]
# Task 6

# %% [markdown]
# ## Part 2: Continuous-Time model

# %% [markdown]
# Task 8

# %% [markdown]
# Task 9

# %% [markdown]
# Task 10 (Optional)

# %% [markdown]
# Task 11

# %% [markdown]
# ### Part 3: Estimation
# Task 12

# %% [markdown]
# Task 13
